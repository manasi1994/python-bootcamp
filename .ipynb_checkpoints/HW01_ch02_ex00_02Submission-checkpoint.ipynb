# %% [markdown]
# # HW01_ch02_ex00_02
#
# ## Question : Run the commands given below in the interpreter and print the output.
# - width = 17
# - height = 12.0
# - delimiter = '.'
#     - width/2
#     - width/2.0
#     - height/3
#     - 1 + 2 * 5
#     - delimiter * 5

# %%
#Output1

""""Python 3.7.3 (default, Mar 27 2019, 16:54:48) 
[Clang 4.0.1 (tags/RELEASE_401/final)] :: Anaconda, Inc. on darwin
Type "help", "copyright", "credits" or "license" for more information.
>>> width=17
>>> height=12.0
>>> delimeter='.'
>>> type(width/2)
<class 'float'>
>>> width/2
8.5
>>> """


#Comments:
#Division returns a result in float,although both the numbers are int.


#Output2
"""">>> width/2.0
8.5
>>> type(width/2.0)
<class 'float'>
>>> """


#Comments:
#Division returns a result in float,although both the numbers are int.


#Output3
"""
>>> height/3
4.0
>>> type(height/3)
<class 'float'>
>>> """


#Comments:
#Division returns a result in float,although both the numbers are int.

#Output3
"""
>>> 1+2*5
11
>>> type(1+2*5)
<class 'int'>

"""

#Comments: Follows BODMAS

#Output4
""""
>>> delimeter*5
'.....'
>>> type(delimeter*5)
<class 'str'>
>>> 

"""

#Comments:Mathematical operations can be applied on strings
